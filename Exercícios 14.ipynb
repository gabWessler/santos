# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
num_rows = 50

# %%
data = {
    'Produto': [f'Produto_{i}' for i in range(1, num_rows + 1)],
    'Categoria': np.random.choice(['Televisão', 'Computador', 'Celular', 'Tablet', 'Impressora'], size=num_rows),
    'Preço': np.random.uniform(100.0, 2000.0, size=num_rows).round(2),
    'Quantidade_Estoque': np.random.randint(1, 50, size=num_rows)}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        Produto   Categoria    Preço  Quantidade_Estoque
# 0    Produto_1   Televisão   324.03                  41
# 1    Produto_2  Impressora   538.48                   1
# 2    Produto_3      Tablet   835.45                  34
# 3    Produto_4  Computador   845.67                  11
# 4    Produto_5   Televisão   839.99                  19
# 5    Produto_6  Computador   281.98                  32
# 6    Produto_7     Celular   283.35                  49
# 7    Produto_8  Impressora  1863.36                  32
# 8    Produto_9  Impressora   816.05                   6
# 9   Produto_10   Televisão   898.08                  27
# 10  Produto_11  Computador   632.97                  31
# 11  Produto_12  Impressora  1407.93                   1
# 12  Produto_13      Tablet  1085.27                  17
# 13  Produto_14      Tablet  1878.44                   8
# 14  Produto_15      Tablet   202.53                  19
# 15  Produto_16  Computador   807.80                  39
# 16  Produto_17  Computador   445.28                  27
# 17  Produto_18  Computador   200.86                   2
# 18  Produto_19     Celular   664.54                  23
# 19  Produto_20  Computador  1905.86                  41
# 20  Produto_21  Impressora  1573.25                  36
# 21  Produto_22     Celular   395.16                  12
# 22  Produto_23  Impressora   283.04                  42
# 23  Produto_24      Tablet   482.74                   8
# 24  Produto_25     Celular  1947.70                  19
# 25  Produto_26   Televisão  1644.97                   4
# 26  Produto_27     Celular   209.68                  10
# 27  Produto_28   Televisão   977.78                   4
# 28  Produto_29  Impressora  1808.34                  24
# 29  Produto_30      Tablet   750.60                  10
# 30  Produto_31   Televisão  1658.20                  13
# 31  Produto_32      Tablet  1466.38                   5
# 32  Produto_33  Computador  1411.54                  12
# 33  Produto_34   Televisão   738.68                  24
# 34  Produto_35      Tablet   431.70                  43
# 35  Produto_36  Computador   686.40                  26
# 36  Produto_37   Televisão   288.50                   1
# 37  Produto_38   Televisão   165.10                  35
# 38  Produto_39      Tablet   420.78                   8
# 39  Produto_40     Celular  1977.56                  14
# 40  Produto_41  Impressora  1806.40                  49
# 41  Produto_42      Tablet  1009.86                   7
# 42  Produto_43  Impressora  1341.69                  32
# 43  Produto_44  Computador  1834.22                  38
# 44  Produto_45  Impressora  1625.26                  11
# 45  Produto_46      Tablet  1559.71                  19
# 46  Produto_47   Televisão   585.94                  20
# 47  Produto_48  Impressora  1021.43                  23
# 48  Produto_49  Impressora   396.81                  22
# 49  Produto_50     Celular   897.98                   1

# %%
df['Multiplicação'] = df['Preço'] * df['Quantidade_Estoque'] #2

# %%
def multiplicar(x):
    return x['Preço'] * x['Quantidade_Estoque'] #3

# %%
df['Resultado'] = df.apply(multiplicar, axis = 1)

# %%
df
# Out:
#        Produto   Categoria    Preço  Quantidade_Estoque  Multiplicação  \
# 0    Produto_1   Televisão   324.03                  41       13285.23
# 1    Produto_2  Impressora   538.48                   1         538.48
# 2    Produto_3      Tablet   835.45                  34       28405.30
# 3    Produto_4  Computador   845.67                  11        9302.37
# 4    Produto_5   Televisão   839.99                  19       15959.81
# 5    Produto_6  Computador   281.98                  32        9023.36
# 6    Produto_7     Celular   283.35                  49       13884.15
# 7    Produto_8  Impressora  1863.36                  32       59627.52
# 8    Produto_9  Impressora   816.05                   6        4896.30
# 9   Produto_10   Televisão   898.08                  27       24248.16
# 10  Produto_11  Computador   632.97                  31       19622.07
# 11  Produto_12  Impressora  1407.93                   1        1407.93
# 12  Produto_13      Tablet  1085.27                  17       18449.59
# 13  Produto_14      Tablet  1878.44                   8       15027.52
# 14  Produto_15      Tablet   202.53                  19        3848.07
# 15  Produto_16  Computador   807.80                  39       31504.20
# 16  Produto_17  Computador   445.28                  27       12022.56
# 17  Produto_18  Computador   200.86                   2         401.72
# 18  Produto_19     Celular   664.54                  23       15284.42
# 19  Produto_20  Computador  1905.86                  41       78140.26
# 20  Produto_21  Impressora  1573.25                  36       56637.00
# 21  Produto_22     Celular   395.16                  12        4741.92
# 22  Produto_23  Impressora   283.04                  42       11887.68
# 23  Produto_24      Tablet   482.74                   8        3861.92
# 24  Produto_25     Celular  1947.70                  19       37006.30
# 25  Produto_26   Televisão  1644.97                   4        6579.88
# 26  Produto_27     Celular   209.68                  10        2096.80
# 27  Produto_28   Televisão   977.78                   4        3911.12
# 28  Produto_29  Impressora  1808.34                  24       43400.16
# 29  Produto_30      Tablet   750.60                  10        7506.00
# 30  Produto_31   Televisão  1658.20                  13       21556.60
# 31  Produto_32      Tablet  1466.38                   5        7331.90
# 32  Produto_33  Computador  1411.54                  12       16938.48
# 33  Produto_34   Televisão   738.68                  24       17728.32
# 34  Produto_35      Tablet   431.70                  43       18563.10
# 35  Produto_36  Computador   686.40                  26       17846.40
# 36  Produto_37   Televisão   288.50                   1         288.50
# 37  Produto_38   Televisão   165.10                  35        5778.50
# 38  Produto_39      Tablet   420.78                   8        3366.24
# 39  Produto_40     Celular  1977.56                  14       27685.84
# 40  Produto_41  Impressora  1806.40                  49       88513.60
# 41  Produto_42      Tablet  1009.86                   7        7069.02
# 42  Produto_43  Impressora  1341.69                  32       42934.08
# 43  Produto_44  Computador  1834.22                  38       69700.36
# 44  Produto_45  Impressora  1625.26                  11       17877.86
# 45  Produto_46      Tablet  1559.71                  19       29634.49
# 46  Produto_47   Televisão   585.94                  20       11718.80
# 47  Produto_48  Impressora  1021.43                  23       23492.89
# 48  Produto_49  Impressora   396.81                  22        8729.82
# 49  Produto_50     Celular   897.98                   1         897.98
#
#     Resultado
# 0    13285.23
# 1      538.48
# 2    28405.30
# 3     9302.37
# 4    15959.81
# 5     9023.36
# 6    13884.15
# 7    59627.52
# 8     4896.30
# 9    24248.16
# 10   19622.07
# 11    1407.93
# 12   18449.59
# 13   15027.52
# 14    3848.07
# 15   31504.20
# 16   12022.56
# 17     401.72
# 18   15284.42
# 19   78140.26
# 20   56637.00
# 21    4741.92
# 22   11887.68
# 23    3861.92
# 24   37006.30
# 25    6579.88
# 26    2096.80
# 27    3911.12
# 28   43400.16
# 29    7506.00
# 30   21556.60
# 31    7331.90
# 32   16938.48
# 33   17728.32
# 34   18563.10
# 35   17846.40
# 36     288.50
# 37    5778.50
# 38    3366.24
# 39   27685.84
# 40   88513.60
# 41    7069.02
# 42   42934.08
# 43   69700.36
# 44   17877.86
# 45   29634.49
# 46   11718.80
# 47   23492.89
# 48    8729.82
# 49     897.98

# %%
df['Resultado'].min()  #4
# Out:
# np.float64(288.5)

# %%
df['Resultado'].max() #4
# Out:
# np.float64(88513.6)

# %%
df['Resultado'].std() #4
# Out:
# np.float64(20456.995245343078)

# %%
df['Resultado'].mean() #4
# Out:
# np.float64(19803.2116)

# %%
df_filtro = (df['Categoria'] == 'Computador') #5

# %%
df_filtro2 = (df['Categoria'] == 'Computador') & (df['Preço'] > 500) #5

# %%
df_filtro3 = (df['Quantidade_Estoque'] > 40 | (df['Categoria'] == 'Impressora'))  #5

# %%
caminho = r'C:\Users\gabriel_w_costa\Documents\excel\excel.xlsx'

# %%
df.to_excel(caminho)

# %%
#acabou

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\gabriel_w_costa\appdata\roaming\python\python39\site-packages (1.5.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gabriel_w_costa\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\gabriel_w_costa\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gabriel_w_costa\appdata\roaming\python\python39\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\gabriel_w_costa\appdata\roaming\python\python39\site-packages (from scikit-learn) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
caminho_arquivo=r'C:\Users\gabriel_w_costa\Downloads\Frutas.xlsx'

# %%
df_frutas = pd.read_excel(caminho_arquivo)

# %%
df_frutas
# Out:
#      Fruta     Cor        Gosto      Formato    Casca
# 0     Limão     Verde      Azedo      Oval       Liso
# 1   Limão     Amarelo    Azedo      Oval       Peludo
# 2     Limão     Verde      Doce       Oval       Liso
# 3     Limão     Amarelo    Azedo      Oval       Liso
# 4   Limão     Verde      Doce       Oval       Peludo
# 5     Banana    Amarelo    Doce       Curvado    Liso
# 6     Banana    Amarelo    Doce       Curvado    Liso
# 7   Banana    Amarelo    Doce       Curvado    Peludo
# 8   Banana    Amarelo    Azedo      Curvado    Peludo
# 9   Banana    Amarelo    Doce       Curvado    Peludo
# 10    Abacaxi   Amarelo    Doce       Alongado   Liso
# 11    Abacaxi   Marrom     Doce       Alongado   Liso
# 12  Abacaxi   Amarelo    Azedo      Alongado   Peludo
# 13  Abacaxi   Amarelo    Azedo      Alongado   Peludo
# 14  Abacaxi   Amarelo    Doce       Alongado   Peludo
# 15    Abacaxi   Amarelo    Doce       Alongado   Liso
# 16  Abacaxi   Amarelo    Doce       Alongado   Peludo
# 17    Abacaxi   Amarelo    Doce       Alongado   Liso
# 18    Abacaxi   Marrom     Doce       Alongado   Liso
# 19    Abacaxi   Amarelo    Doce       Alongado   Liso
# 20    Kiwi      Marrom     Azedo      Oval       Liso
# 21  Kiwi      Verde      Doce       Oval       Peludo
# 22    Kiwi      Marrom     Doce       Oval       Liso
# 23    Kiwi      Verde      Azedo      Oval       Liso
# 24    Kiwi      Marrom     Doce       Oval       Liso
# 25    Kiwi      Marrom     Azedo      Oval       Liso
# 26  Kiwi      Marrom     Doce       Oval       Peludo
# 27  Kiwi      Marrom     Azedo      Oval       Peludo
# 28    Kiwi      Verde      Azedo      Oval       Liso
# 29  Kiwi      Verde      Doce       Oval       Peludo
# 30  Kiwi      Verde      Azedo      Oval       Peludo
# 31    Kiwi      Marrom     Azedo      Oval       Liso
# 32  Kiwi      Verde      Azedo      Oval       Peludo
# 33    Kiwi      Marrom     Azedo      Oval       Liso
# 34    Kiwi      Marrom     Azedo      Oval       Liso

# %%
df_frutas = df_frutas['Fruta     Cor        Gosto      Formato    Casca'].str.split(expand=True)

# %%
df_frutas.columns = ['Frutas', 'Cor', 'Sabor', 'Formato', 'Textura']

# %%
df_frutas
# Out:
#      Frutas      Cor  Sabor   Formato Textura
# 0     Limão    Verde  Azedo      Oval    Liso
# 1     Limão  Amarelo  Azedo      Oval  Peludo
# 2     Limão    Verde   Doce      Oval    Liso
# 3     Limão  Amarelo  Azedo      Oval    Liso
# 4     Limão    Verde   Doce      Oval  Peludo
# 5    Banana  Amarelo   Doce   Curvado    Liso
# 6    Banana  Amarelo   Doce   Curvado    Liso
# 7    Banana  Amarelo   Doce   Curvado  Peludo
# 8    Banana  Amarelo  Azedo   Curvado  Peludo
# 9    Banana  Amarelo   Doce   Curvado  Peludo
# 10  Abacaxi  Amarelo   Doce  Alongado    Liso
# 11  Abacaxi   Marrom   Doce  Alongado    Liso
# 12  Abacaxi  Amarelo  Azedo  Alongado  Peludo
# 13  Abacaxi  Amarelo  Azedo  Alongado  Peludo
# 14  Abacaxi  Amarelo   Doce  Alongado  Peludo
# 15  Abacaxi  Amarelo   Doce  Alongado    Liso
# 16  Abacaxi  Amarelo   Doce  Alongado  Peludo
# 17  Abacaxi  Amarelo   Doce  Alongado    Liso
# 18  Abacaxi   Marrom   Doce  Alongado    Liso
# 19  Abacaxi  Amarelo   Doce  Alongado    Liso
# 20     Kiwi   Marrom  Azedo      Oval    Liso
# 21     Kiwi    Verde   Doce      Oval  Peludo
# 22     Kiwi   Marrom   Doce      Oval    Liso
# 23     Kiwi    Verde  Azedo      Oval    Liso
# 24     Kiwi   Marrom   Doce      Oval    Liso
# 25     Kiwi   Marrom  Azedo      Oval    Liso
# 26     Kiwi   Marrom   Doce      Oval  Peludo
# 27     Kiwi   Marrom  Azedo      Oval  Peludo
# 28     Kiwi    Verde  Azedo      Oval    Liso
# 29     Kiwi    Verde   Doce      Oval  Peludo
# 30     Kiwi    Verde  Azedo      Oval  Peludo
# 31     Kiwi   Marrom  Azedo      Oval    Liso
# 32     Kiwi    Verde  Azedo      Oval  Peludo
# 33     Kiwi   Marrom  Azedo      Oval    Liso
# 34     Kiwi   Marrom  Azedo      Oval    Liso

# %%
y = df_frutas['Frutas']

# %%
X = df_frutas[['Cor', 'Sabor', 'Formato', 'Textura']]

# %%
mapeamento_cor = {'Verde': 0, 'Amarelo': 1, 'Marrom': 2}
mapeamento_sabor = {'Azedo': 0, 'Doce': 1}
mapeamento_formato = {'Oval': 0, 'Curvado': 1, 'Alongado':2}
mapeamento_textura = {'Liso': 0, 'Peludo': 1}

# %%
X['Cor'] = X['Cor'].map(mapeamento_cor)
X['Sabor'] = X['Sabor'].map(mapeamento_sabor)
X['Formato'] = X['Formato'].map(mapeamento_formato)
X['Textura'] = X['Textura'].map(mapeamento_textura)
# Out:
# C:\Users\gabriel_w_costa\AppData\Local\Temp\ipykernel_15872\3599940596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Cor'] = X['Cor'].map(mapeamento_cor)
# C:\Users\gabriel_w_costa\AppData\Local\Temp\ipykernel_15872\3599940596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Sabor'] = X['Sabor'].map(mapeamento_sabor)
# C:\Users\gabriel_w_costa\AppData\Local\Temp\ipykernel_15872\3599940596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Formato'] = X['Formato'].map(mapeamento_formato)
# C:\Users\gabriel_w_costa\AppData\Local\Temp\ipykernel_15872\3599940596.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Textura'] = X['Textura'].map(mapeamento_textura)

# %%
X
# Out:
#     Cor  Sabor  Formato  Textura
# 0     0      0        0        0
# 1     1      0        0        1
# 2     0      1        0        0
# 3     1      0        0        0
# 4     0      1        0        1
# 5     1      1        1        0
# 6     1      1        1        0
# 7     1      1        1        1
# 8     1      0        1        1
# 9     1      1        1        1
# 10    1      1        2        0
# 11    2      1        2        0
# 12    1      0        2        1
# 13    1      0        2        1
# 14    1      1        2        1
# 15    1      1        2        0
# 16    1      1        2        1
# 17    1      1        2        0
# 18    2      1        2        0
# 19    1      1        2        0
# 20    2      0        0        0
# 21    0      1        0        1
# 22    2      1        0        0
# 23    0      0        0        0
# 24    2      1        0        0
# 25    2      0        0        0
# 26    2      1        0        1
# 27    2      0        0        1
# 28    0      0        0        0
# 29    0      1        0        1
# 30    0      0        0        1
# 31    2      0        0        0
# 32    0      0        0        1
# 33    2      0        0        0
# 34    2      0        0        0

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=37)

# %%
modelo = DecisionTreeClassifier()

# %%
modelo._fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
previsoes = modelo.predict(X_test)

# %%
caminho_arquivo2 = r'C:\Users\gabriel_w_costa\Downloads\Frutas2.xlsx' 
df_frutas2 = pd.read_excel(caminho_arquivo2)

# %%
df_frutas2['Cor'] = df_frutas2['Cor'].map(mapeamento_cor)
df_frutas2['Sabor'] = df_frutas2['Sabor'].map(mapeamento_sabor)
df_frutas2['Formato'] = df_frutas2['Formato'].map(mapeamento_formato)
df_frutas2['Textura'] = df_frutas2['Textura'].map(mapeamento_textura)

# %%
previsoes_novo_dados = modelo.predict(df_frutas2)

# %%
previsoes_novo_dados
# Out:
# array(['Banana', 'Kiwi', 'Banana', 'Kiwi'], dtype=object)

# %%
df_frutas2
# Out:
#    Cor  Sabor  Formato  Textura
# 0    1      1        1        0
# 1    2      0        0        1
# 2    1      1        1        0
# 3    0      0        0        0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
caminho_arquivo3=r'C:\Users\gabriel_w_costa\Downloads\cliente_compras.xlsx'

# %%
df_cliente = pd.read_excel(caminho_arquivo3)

# %%
df_cliente.columns = ['tempo_gasto_site', 'numero_itens_visualizados', 'compras_anteriores', 'compra']

# %%
x = df_cliente[['tempo_gasto_site', 'numero_itens_visualizados', 'compras_anteriores', 'compra']]

# %%
df_cliente
# Out:
#     tempo_gasto_site  numero_itens_visualizados compras_anteriores compra
# 0                 10                          5                Não    Não
# 1                 15                          7                Sim    Sim
# 2                 20                          8                Sim    Sim
# 3                  5                          3                Não    Não
# 4                 25                         10                Sim    Sim
# 5                 30                         12                Sim    Sim
# 6                  8                          4                Não    Não
# 7                 12                          6                Sim    Sim
# 8                 18                          9                Sim    Sim
# 9                  7                          3                Não    Não
# 10                22                         11                Sim    Sim
# 11                28                         13                Sim    Sim
# 12                 6                          2                Não    Não
# 13                14                          7                Sim    Sim
# 14                16                          8                Sim    Sim
# 15                 9                          4                Não    Não
# 16                24                         10                Sim    Sim
# 17                32                         14                Sim    Sim
# 18                11                          5                Não    Não
# 19                21                          9                Sim    Sim
# 20                26                         11                Sim    Sim
# 21                13                          6                Sim    Sim
# 22                19                          8                Sim    Sim
# 23                17                          7                Sim    Sim
# 24                23                         10                Sim    Sim
# 25                27                         12                Sim    Sim
# 26                29                         13                Sim    Sim
# 27                31                         14                Sim    Sim
# 28                33                         15                Sim    Sim
# 29                35                         16                Sim    Sim
# 30                37                         17                Sim    Sim
# 31                39                         18                Sim    Sim
# 32                41                         19                Sim    Sim
# 33                43                         20                Sim    Sim
# 34                45                         21                Sim    Sim
# 35                47                         22                Sim    Sim
# 36                49                         23                Sim    Sim
# 37                51                         24                Sim    Sim
# 38                53                         25                Sim    Sim
# 39                55                         26                Sim    Sim
# 40                57                         27                Sim    Sim
# 41                59                         28                Sim    Sim
# 42                61                         29                Sim    Sim
# 43                63                         30                Sim    Sim
# 44                65                         31                Sim    Sim
# 45                67                         32                Sim    Sim
# 46                69                         33                Sim    Sim
# 47                71                         34                Sim    Sim

# %%
mapeamento_compras_anteriores = {'Sim':0, 'Não':1}
mapeamento_compra = {'Sim':0, 'Não':1}

# %%
x['compras_anteriores'] = x['compras_anteriores'].map(mapeamento_compras_anteriores)
x['compra'] = x['compra'].map(mapeamento_compra)

# %%
x
# Out:
#     tempo_gasto_site  numero_itens_visualizados  compras_anteriores  compra
# 0                 10                          5                   1       1
# 1                 15                          7                   0       0
# 2                 20                          8                   0       0
# 3                  5                          3                   1       1
# 4                 25                         10                   0       0
# 5                 30                         12                   0       0
# 6                  8                          4                   1       1
# 7                 12                          6                   0       0
# 8                 18                          9                   0       0
# 9                  7                          3                   1       1
# 10                22                         11                   0       0
# 11                28                         13                   0       0
# 12                 6                          2                   1       1
# 13                14                          7                   0       0
# 14                16                          8                   0       0
# 15                 9                          4                   1       1
# 16                24                         10                   0       0
# 17                32                         14                   0       0
# 18                11                          5                   1       1
# 19                21                          9                   0       0
# 20                26                         11                   0       0
# 21                13                          6                   0       0
# 22                19                          8                   0       0
# 23                17                          7                   0       0
# 24                23                         10                   0       0
# 25                27                         12                   0       0
# 26                29                         13                   0       0
# 27                31                         14                   0       0
# 28                33                         15                   0       0
# 29                35                         16                   0       0
# 30                37                         17                   0       0
# 31                39                         18                   0       0
# 32                41                         19                   0       0
# 33                43                         20                   0       0
# 34                45                         21                   0       0
# 35                47                         22                   0       0
# 36                49                         23                   0       0
# 37                51                         24                   0       0
# 38                53                         25                   0       0
# 39                55                         26                   0       0
# 40                57                         27                   0       0
# 41                59                         28                   0       0
# 42                61                         29                   0       0
# 43                63                         30                   0       0
# 44                65                         31                   0       0
# 45                67                         32                   0       0
# 46                69                         33                   0       0
# 47                71                         34                   0       0
